# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import io
from time import sleep
import datetime
from functools import reduce
# Out:
# /Users/markus/Documents/Projects/Soccer/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
yearStart = 2019 # earlier than 2017 doesn't have some of the required columns and tables # earlier than 2019 raises an error at 2019 1
yearEnd = 2023

# %%
def get_current_year():
	today = datetime.date.today()
	return today.year

# %%
def get_premier_league_url(season_begin_year: int):
	default_url_prefix = "https://fbref.com/en/comps/12/"
	default_url_suffix = "La-Liga-Stats"

	if(season_begin_year > 2023):
		raise ValueError("Year " + str(season_begin_year) + " didn't happen yet!")
	elif(season_begin_year == 2023):
		return default_url_prefix + default_url_suffix
	return default_url_prefix + str(season_begin_year) + "-" + str(season_begin_year + 1) + "/" + str(season_begin_year) + "-" + str(season_begin_year + 1) + "-" + default_url_suffix

# %%
def get_team_urls(premier_league_url: str):
	premier_league_data = requests.get(premier_league_url)

	if(premier_league_data.status_code != 200):
		print(premier_league_data.status_code)
		retry_after = int(premier_league_data.headers['Retry-After'])
		print(retry_after)
		return
	
	premier_league_soup = BeautifulSoup(premier_league_data.text)
	teams_table = premier_league_soup.select('table.stats_table')[0]

	links = list(filter(lambda x: x is not None, [l.get("href") if "squad" in l.get("href") else None for l in teams_table.find_all('a')]))
	team_urls = [f"https://fbref.com{l}" for l in links]

	return team_urls

# %%
def write_list_into_csv(all_matches: list, name: str):
	match_df = pd.concat(all_matches)
	match_df.columns = [c.lower() for c in match_df.columns]
	match_df.to_csv(name)

# %%
all_matches = []
for year in range(yearStart, yearEnd + 1):
	team_urls = get_team_urls(get_premier_league_url(year))

	index = 0
	for team_url in team_urls:
		sleep(4)
		team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")

		print("Current year: " + str(year) + " in interval " + str(yearStart) + "-" + str(yearEnd))
		print("Current team: " + team_name + " being " + str(index + 1) + "/" + str(len(team_urls)))
		print(team_url)
		
		team_data = requests.get(team_url)
		team_soup = BeautifulSoup(team_data.text)

		team_links = [l.get("href") for l in team_soup.find_all('a')]
		
		team_links_schedule = [l for l in team_links if l and 'matchlogs/c12/schedule' in l] # Scores & Fixtures
		team_links_shooting = [l for l in team_links if l and 'matchlogs/c12/shooting' in l] # Shooting
		team_links_keeper = [l for l in team_links if l and 'matchlogs/c12/keeper' in l] # Goalkeeping
		team_links_passing = [l for l in team_links if l and 'matchlogs/c12/passing' in l] # Passing
		team_links_passing_types = [l for l in team_links if l and 'matchlogs/c12/passing_types' in l] # Pass Types
		team_links_gca = [l for l in team_links if l and 'matchlogs/c12/gca' in l] # Goal and Shot Creation
		team_links_defensive = [l for l in team_links if l and 'matchlogs/c12/defense' in l] # Defensive Actions
		team_links_possession = [l for l in team_links if l and 'matchlogs/c12/possession' in l] # Possession
		team_links_misc = [l for l in team_links if l and 'matchlogs/c12/misc' in l] # Miscellaneous Stats

		sleep(4)
		schedule_data = requests.get(f"https://fbref.com{team_links_schedule[0]}")
		schedule_html = pd.read_html(io.StringIO(schedule_data.text), match="Scores & Fixtures")[0]
		schedule_html = schedule_html.dropna(subset=['Result'])

		sleep(4)
		shooting_data = requests.get(f"https://fbref.com{team_links_shooting[0]}")
		shooting_html = pd.read_html(io.StringIO(shooting_data.text), match="Shooting")[0]
		shooting_html.columns = shooting_html.columns.droplevel()

		sleep(4)
		keeper_data = requests.get(f"https://fbref.com{team_links_keeper[0]}")
		keeper_html = pd.read_html(io.StringIO(keeper_data.text), match="Goalkeeping")[0]
		keeper_html.columns = keeper_html.columns.droplevel()

		sleep(4)
		passing_data = requests.get(f"https://fbref.com{team_links_passing[0]}")
		passing_html = pd.read_html(io.StringIO(passing_data.text), match="Passing")[0]
		passing_html.columns = passing_html.columns.droplevel()

		sleep(4)
		passing_types_data = requests.get(f"https://fbref.com{team_links_passing_types[0]}")
		passing_types_html = pd.read_html(io.StringIO(passing_types_data.text), match="Pass Types")[0]
		passing_types_html.columns = passing_types_html.columns.droplevel()

		sleep(4)
		gca_data = requests.get(f"https://fbref.com{team_links_gca[0]}")
		gca_html = pd.read_html(io.StringIO(gca_data.text), match="Goal and Shot Creation")[0]
		gca_html.columns = gca_html.columns.droplevel()

		sleep(4)
		defensive_actions_data = requests.get(f"https://fbref.com{team_links_defensive[0]}")
		defensive_actions_html = pd.read_html(io.StringIO(defensive_actions_data.text), match="Defensive Actions")[0]
		defensive_actions_html.columns = defensive_actions_html.columns.droplevel()

		sleep(4)
		possession_data = requests.get(f"https://fbref.com{team_links_possession[0]}")
		possession_html = pd.read_html(io.StringIO(possession_data.text), match="Possession")[0]
		possession_html.columns = possession_html.columns.droplevel()

		sleep(4)
		misc_data = requests.get(f"https://fbref.com{team_links_misc[0]}")
		misc_html = pd.read_html(io.StringIO(misc_data.text), match="Miscellaneous Stats")[0]
		misc_html.columns = misc_html.columns.droplevel()

		dfs = [schedule_html, shooting_html, keeper_html, passing_html, passing_types_html, gca_html, defensive_actions_html, possession_html, misc_html]
		# dfs = [schedule_html, shooting_html]

		team_data_end = reduce(lambda left,right: pd.merge(left,right,on='Date', suffixes=('', '_drop')), dfs)
		team_data_end.drop([col for col in team_data_end.columns if 'drop' in col], axis=1, inplace=True)
	
		team_data_end["Season"] = str(year) + "-" + str(year + 1)
		team_data_end["Team"] = team_name

		all_matches.append(team_data_end)
		index += 1
# Out:
# Current year: 2019 in interval 2019-2023
# Current team: Real Madrid being 1/20
# https://fbref.com/en/squads/53a2f082/2019-2020/Real-Madrid-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Barcelona being 2/20
# https://fbref.com/en/squads/206d90db/2019-2020/Barcelona-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Atletico Madrid being 3/20
# https://fbref.com/en/squads/db3b9613/2019-2020/Atletico-Madrid-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Sevilla being 4/20
# https://fbref.com/en/squads/ad2be733/2019-2020/Sevilla-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Villarreal being 5/20
# https://fbref.com/en/squads/2a8183b3/2019-2020/Villarreal-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Real Sociedad being 6/20
# https://fbref.com/en/squads/e31d1cd9/2019-2020/Real-Sociedad-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Granada being 7/20
# https://fbref.com/en/squads/a0435291/2019-2020/Granada-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Getafe being 8/20
# https://fbref.com/en/squads/7848bd64/2019-2020/Getafe-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Valencia being 9/20
# https://fbref.com/en/squads/dcc91a7b/2019-2020/Valencia-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Osasuna being 10/20
# https://fbref.com/en/squads/03c57e2b/2019-2020/Osasuna-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Athletic Club being 11/20
# https://fbref.com/en/squads/2b390eca/2019-2020/Athletic-Club-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Levante being 12/20
# https://fbref.com/en/squads/9800b6a1/2019-2020/Levante-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Valladolid being 13/20
# https://fbref.com/en/squads/17859612/2019-2020/Valladolid-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Eibar being 14/20
# https://fbref.com/en/squads/bea5c710/2019-2020/Eibar-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Real Betis being 15/20
# https://fbref.com/en/squads/fc536746/2019-2020/Real-Betis-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Alaves being 16/20
# https://fbref.com/en/squads/8d6fd021/2019-2020/Alaves-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Celta Vigo being 17/20
# https://fbref.com/en/squads/f25da7fb/2019-2020/Celta-Vigo-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Leganes being 18/20
# https://fbref.com/en/squads/7c6f2c78/2019-2020/Leganes-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Mallorca being 19/20
# https://fbref.com/en/squads/2aa12281/2019-2020/Mallorca-Stats
# Current year: 2019 in interval 2019-2023
# Current team: Espanyol being 20/20
# https://fbref.com/en/squads/a8661628/2019-2020/Espanyol-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Atletico Madrid being 1/20
# https://fbref.com/en/squads/db3b9613/2020-2021/Atletico-Madrid-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Real Madrid being 2/20
# https://fbref.com/en/squads/53a2f082/2020-2021/Real-Madrid-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Barcelona being 3/20
# https://fbref.com/en/squads/206d90db/2020-2021/Barcelona-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Sevilla being 4/20
# https://fbref.com/en/squads/ad2be733/2020-2021/Sevilla-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Real Sociedad being 5/20
# https://fbref.com/en/squads/e31d1cd9/2020-2021/Real-Sociedad-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Real Betis being 6/20
# https://fbref.com/en/squads/fc536746/2020-2021/Real-Betis-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Villarreal being 7/20
# https://fbref.com/en/squads/2a8183b3/2020-2021/Villarreal-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Celta Vigo being 8/20
# https://fbref.com/en/squads/f25da7fb/2020-2021/Celta-Vigo-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Granada being 9/20
# https://fbref.com/en/squads/a0435291/2020-2021/Granada-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Athletic Club being 10/20
# https://fbref.com/en/squads/2b390eca/2020-2021/Athletic-Club-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Osasuna being 11/20
# https://fbref.com/en/squads/03c57e2b/2020-2021/Osasuna-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Cadiz being 12/20
# https://fbref.com/en/squads/ee7c297c/2020-2021/Cadiz-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Valencia being 13/20
# https://fbref.com/en/squads/dcc91a7b/2020-2021/Valencia-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Levante being 14/20
# https://fbref.com/en/squads/9800b6a1/2020-2021/Levante-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Getafe being 15/20
# https://fbref.com/en/squads/7848bd64/2020-2021/Getafe-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Alaves being 16/20
# https://fbref.com/en/squads/8d6fd021/2020-2021/Alaves-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Elche being 17/20
# https://fbref.com/en/squads/6c8b07df/2020-2021/Elche-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Huesca being 18/20
# https://fbref.com/en/squads/c6c493e6/2020-2021/Huesca-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Valladolid being 19/20
# https://fbref.com/en/squads/17859612/2020-2021/Valladolid-Stats
# Current year: 2020 in interval 2019-2023
# Current team: Eibar being 20/20
# https://fbref.com/en/squads/bea5c710/2020-2021/Eibar-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Real Madrid being 1/20
# https://fbref.com/en/squads/53a2f082/2021-2022/Real-Madrid-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Barcelona being 2/20
# https://fbref.com/en/squads/206d90db/2021-2022/Barcelona-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Atletico Madrid being 3/20
# https://fbref.com/en/squads/db3b9613/2021-2022/Atletico-Madrid-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Sevilla being 4/20
# https://fbref.com/en/squads/ad2be733/2021-2022/Sevilla-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Real Betis being 5/20
# https://fbref.com/en/squads/fc536746/2021-2022/Real-Betis-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Real Sociedad being 6/20
# https://fbref.com/en/squads/e31d1cd9/2021-2022/Real-Sociedad-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Villarreal being 7/20
# https://fbref.com/en/squads/2a8183b3/2021-2022/Villarreal-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Athletic Club being 8/20
# https://fbref.com/en/squads/2b390eca/2021-2022/Athletic-Club-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Valencia being 9/20
# https://fbref.com/en/squads/dcc91a7b/2021-2022/Valencia-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Osasuna being 10/20
# https://fbref.com/en/squads/03c57e2b/2021-2022/Osasuna-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Celta Vigo being 11/20
# https://fbref.com/en/squads/f25da7fb/2021-2022/Celta-Vigo-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Rayo Vallecano being 12/20
# https://fbref.com/en/squads/98e8af82/2021-2022/Rayo-Vallecano-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Elche being 13/20
# https://fbref.com/en/squads/6c8b07df/2021-2022/Elche-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Espanyol being 14/20
# https://fbref.com/en/squads/a8661628/2021-2022/Espanyol-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Getafe being 15/20
# https://fbref.com/en/squads/7848bd64/2021-2022/Getafe-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Mallorca being 16/20
# https://fbref.com/en/squads/2aa12281/2021-2022/Mallorca-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Cadiz being 17/20
# https://fbref.com/en/squads/ee7c297c/2021-2022/Cadiz-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Granada being 18/20
# https://fbref.com/en/squads/a0435291/2021-2022/Granada-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Levante being 19/20
# https://fbref.com/en/squads/9800b6a1/2021-2022/Levante-Stats
# Current year: 2021 in interval 2019-2023
# Current team: Alaves being 20/20
# https://fbref.com/en/squads/8d6fd021/2021-2022/Alaves-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Barcelona being 1/20
# https://fbref.com/en/squads/206d90db/2022-2023/Barcelona-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Real Madrid being 2/20
# https://fbref.com/en/squads/53a2f082/2022-2023/Real-Madrid-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Atletico Madrid being 3/20
# https://fbref.com/en/squads/db3b9613/2022-2023/Atletico-Madrid-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Real Sociedad being 4/20
# https://fbref.com/en/squads/e31d1cd9/2022-2023/Real-Sociedad-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Villarreal being 5/20
# https://fbref.com/en/squads/2a8183b3/2022-2023/Villarreal-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Real Betis being 6/20
# https://fbref.com/en/squads/fc536746/2022-2023/Real-Betis-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Osasuna being 7/20
# https://fbref.com/en/squads/03c57e2b/2022-2023/Osasuna-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Athletic Club being 8/20
# https://fbref.com/en/squads/2b390eca/2022-2023/Athletic-Club-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Mallorca being 9/20
# https://fbref.com/en/squads/2aa12281/2022-2023/Mallorca-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Girona being 10/20
# https://fbref.com/en/squads/9024a00a/2022-2023/Girona-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Rayo Vallecano being 11/20
# https://fbref.com/en/squads/98e8af82/2022-2023/Rayo-Vallecano-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Sevilla being 12/20
# https://fbref.com/en/squads/ad2be733/2022-2023/Sevilla-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Celta Vigo being 13/20
# https://fbref.com/en/squads/f25da7fb/2022-2023/Celta-Vigo-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Cadiz being 14/20
# https://fbref.com/en/squads/ee7c297c/2022-2023/Cadiz-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Getafe being 15/20
# https://fbref.com/en/squads/7848bd64/2022-2023/Getafe-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Valencia being 16/20
# https://fbref.com/en/squads/dcc91a7b/2022-2023/Valencia-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Almeria being 17/20
# https://fbref.com/en/squads/78ecf4bb/2022-2023/Almeria-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Valladolid being 18/20
# https://fbref.com/en/squads/17859612/2022-2023/Valladolid-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Espanyol being 19/20
# https://fbref.com/en/squads/a8661628/2022-2023/Espanyol-Stats
# Current year: 2022 in interval 2019-2023
# Current team: Elche being 20/20
# https://fbref.com/en/squads/6c8b07df/2022-2023/Elche-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Girona being 1/20
# https://fbref.com/en/squads/9024a00a/Girona-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Real Madrid being 2/20
# https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Atletico Madrid being 3/20
# https://fbref.com/en/squads/db3b9613/Atletico-Madrid-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Barcelona being 4/20
# https://fbref.com/en/squads/206d90db/Barcelona-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Athletic Club being 5/20
# https://fbref.com/en/squads/2b390eca/Athletic-Club-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Real Sociedad being 6/20
# https://fbref.com/en/squads/e31d1cd9/Real-Sociedad-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Real Betis being 7/20
# https://fbref.com/en/squads/fc536746/Real-Betis-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Valencia being 8/20
# https://fbref.com/en/squads/dcc91a7b/Valencia-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Las Palmas being 9/20
# https://fbref.com/en/squads/0049d422/Las-Palmas-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Getafe being 10/20
# https://fbref.com/en/squads/7848bd64/Getafe-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Alaves being 11/20
# https://fbref.com/en/squads/8d6fd021/Alaves-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Osasuna being 12/20
# https://fbref.com/en/squads/03c57e2b/Osasuna-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Rayo Vallecano being 13/20
# https://fbref.com/en/squads/98e8af82/Rayo-Vallecano-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Villarreal being 14/20
# https://fbref.com/en/squads/2a8183b3/Villarreal-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Mallorca being 15/20
# https://fbref.com/en/squads/2aa12281/Mallorca-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Sevilla being 16/20
# https://fbref.com/en/squads/ad2be733/Sevilla-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Celta Vigo being 17/20
# https://fbref.com/en/squads/f25da7fb/Celta-Vigo-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Cadiz being 18/20
# https://fbref.com/en/squads/ee7c297c/Cadiz-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Granada being 19/20
# https://fbref.com/en/squads/a0435291/Granada-Stats
# Current year: 2023 in interval 2019-2023
# Current team: Almeria being 20/20
# https://fbref.com/en/squads/78ecf4bb/Almeria-Stats

# %%
name = "la_liga_" + str(yearStart) + "-" + str(yearEnd) + ".csv"
write_list_into_csv(all_matches, name)
