# %%
import pandas as pd

# %%
split_date = '2022-10-01'

# %%
matches = pd.read_csv("premier_league_2019-2024.csv", index_col=0)

# %%
matches.shape # rows and columns
# 2 seasons * 20 teams * 38 matches
# Out:
# (3466, 129)

# %%
matches["targetWins"] = (matches["result"] == "W").astype("int")
matches["targetLosses"] = (matches["result"] == "L").astype("int")

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes == 1

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes #each opponent now has their own code

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int") #remove : and minutes, keep just hour
matches["day_code"] = matches["date"].dt.dayofweek

del matches["time"]
del matches["season"]

# %%
matches["formation_code"] = matches["formation"].astype("category").cat.codes #each opponent now has their own code
matches["referee_code"] = matches["referee"].astype("category").cat.codes #each opponent now has their own code

# %%
matches
# Out:
#          date         round  day venue result   gf   ga         opponent   xg  \
# 0  2019-08-09   Matchweek 1  Fri  Home      W  4.0  1.0     Norwich City  1.8
# 1  2019-08-17   Matchweek 2  Sat  Away      W  2.0  1.0      Southampton  1.3
# 2  2019-08-24   Matchweek 3  Sat  Home      W  3.0  1.0          Arsenal  2.5
# 3  2019-08-31   Matchweek 4  Sat  Away      W  3.0  0.0          Burnley  1.0
# 4  2019-09-14   Matchweek 5  Sat  Home      W  3.0  1.0    Newcastle Utd  3.0
# ..        ...           ...  ...   ...    ...  ...  ...              ...  ...
# 17 2023-12-22  Matchweek 18  Fri  Away      D  1.0  1.0      Aston Villa  0.6
# 18 2023-12-26  Matchweek 19  Tue  Home      L  2.0  3.0       Luton Town  2.4
# 19 2023-12-30  Matchweek 20  Sat  Away      L  0.0  2.0  Manchester City  0.3
# 20 2024-01-21  Matchweek 21  Sun  Home      D  2.0  2.0         West Ham  2.5
# 21 2024-01-30  Matchweek 22  Tue  Away      L  2.0  3.0   Crystal Palace  0.8
#
#     xga  ...  won%              team targetWins targetLosses venue_code  \
# 0   0.9  ...  68.2         Liverpool          1            0       True
# 1   1.9  ...  55.9         Liverpool          1            0      False
# 2   1.0  ...  38.9         Liverpool          1            0       True
# 3   0.9  ...  52.3         Liverpool          1            0      False
# 4   0.3  ...  65.8         Liverpool          1            0       True
# ..  ...  ...   ...               ...        ...          ...        ...
# 17  0.9  ...  50.0  Sheffield United          0            0      False
# 18  0.6  ...  50.0  Sheffield United          0            1       True
# 19  2.2  ...  37.5  Sheffield United          0            1      False
# 20  2.3  ...  46.2  Sheffield United          0            0       True
# 21  1.1  ...  66.7  Sheffield United          0            1      False
#
#    opp_code  hour  day_code  formation_code  referee_code
# 0        17    20         4              15            16
# 1        20    15         5              15             0
# 2         0    17         5              15             2
# 3         5    17         5              15             3
# 4        16    12         5              15             0
# ..      ...   ...       ...             ...           ...
# 17        1    20         4               4             2
# 18       13    15         1              17            25
# 19       14    15         5               4             7
# 20       24    14         6              10            17
# 21        7    20         1              10            31
#
# [3466 rows x 135 columns]

# %%
matches.dtypes
# Out:
# date              datetime64[ns]
# round                     object
# day                       object
# venue                     object
# result                    object
#                        ...
# opp_code                    int8
# hour                       int64
# day_code                   int32
# formation_code              int8
# referee_code                int8
# Length: 135, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfWins = RandomForestClassifier(n_estimators=1000, min_samples_split=2, random_state=1, max_depth=3)

# %%
train = matches[matches["date"] < split_date]

# %%
test = matches[matches["date"] > split_date]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "formation_code", "referee_code"]

# %%
rfWins.fit(train[predictors], train["targetWins"])
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=1000, random_state=1)

# %%
predsWins = rfWins.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
errorWins = accuracy_score(test["targetWins"], predsWins)

# %%
print(errorWins)
# Out:
# 0.6107899807321773

# %%
combinedWins = pd.DataFrame(dict(actual=test["targetWins"], predicted=predsWins))

# %%
pd.crosstab(index=combinedWins["actual"], columns=combinedWins["predicted"])
# Out:
# predicted    0  1
# actual
# 0          626  2
# 1          402  8

# %%
from sklearn.metrics import precision_score

precision_score(test["targetWins"], predsWins)
# Out:
# 0.8

# %%
grouped_matches = matches.groupby("team")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/yn/th9j1n395vq70h3nx8132vg00000gn/T/ipykernel_36806/4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < split_date]
    test = data[data["date"] > split_date]

    rfWins.fit(train[predictors], train["targetWins"])

    predsWinsTrain = rfWins.predict(train[predictors])
    predsWinsTest = rfWins.predict(test[predictors])

    # test
    predsProba = rfWins.predict_proba(test[predictors])[:, 1]
    count = 0
    for num in predsProba:
        if(num >= 0.5):
            count += 1
    print(count)

    combinedWinsTrain = pd.DataFrame(dict(actual=train["targetWins"], predicted=predsWinsTrain), index=train.index)
    errorWinsTrain = precision_score(train["targetWins"], predsWinsTrain)

    combinedWinsTest = pd.DataFrame(dict(actual=test["targetWins"], predicted=predsWinsTest), index=test.index)
    errorWinsTest = precision_score(test["targetWins"], predsWinsTest)

    print(errorWinsTrain)
    print(errorWinsTest)

    return combinedWinsTest, errorWinsTest

# %%
combinedWins, errorWins = make_predictions(matches_rolling, predictors + new_cols)
# Out:
# 66
# 0.7454545454545455
# 0.6363636363636364

# %%
combinedWins = combinedWins.merge(matches_rolling[["result", "gf", "ga", "team", "opponent", "venue", "date", "hour", "formation_code", "referee_code"]], left_index=True, right_index=True)

# %%
test = combinedWins[(combinedWins["predicted"] == 1) & (combinedWins["venue"] == "Home") & (combinedWins["hour"] < 16)].sort_values("date")
test
# Out:
#       actual  predicted result   gf   ga                      team  \
# 2001       1          1      W  6.0  3.0           Manchester City
# 2341       1          1      W  5.0  1.0          Newcastle United
# 2002       1          1      W  4.0  0.0           Manchester City
# 2004       1          1      W  3.0  1.0           Manchester City
# 658        1          1      W  1.0  0.0  Brighton and Hove Albion
# 2019       1          1      W  2.0  0.0           Manchester City
# 661        1          1      W  4.0  0.0  Brighton and Hove Albion
# 138        1          1      W  4.0  1.0                   Arsenal
# 139        1          1      W  4.0  1.0                   Arsenal
# 1836       1          1      W  3.0  2.0                 Liverpool
# 1140       0          1      D  0.0  0.0            Crystal Palace
# 2194       1          1      W  1.0  0.0         Manchester United
# 2365       1          1      W  3.0  1.0          Newcastle United
# 2203       1          1      W  3.0  2.0         Manchester United
# 2035       1          1      W  5.0  1.0           Manchester City
# 1150       1          1      W  3.0  2.0            Crystal Palace
# 2920       1          1      W  2.0  1.0         Tottenham Hotspur
# 2037       1          1      W  2.0  0.0           Manchester City
# 985        0          1      L  0.0  1.0                   Chelsea
# 154        0          1      D  2.0  2.0                   Arsenal
# 2379       1          1      W  4.0  0.0          Newcastle United
# 2044       0          1      D  1.0  1.0           Manchester City
# 2933       1          1      W  2.0  1.0         Tottenham Hotspur
# 2050       1          1      W  2.0  0.0           Manchester City
#
#              opponent venue       date  hour  formation_code  referee_code
# 2001   Manchester Utd  Home 2022-10-02    14              15            16
# 2341        Brentford  Home 2022-10-08    15              15            10
# 2002      Southampton  Home 2022-10-08    15              12             1
# 2004         Brighton  Home 2022-10-22    15              15             4
# 658       Bournemouth  Home 2023-02-04    15               4             4
# 2019    Newcastle Utd  Home 2023-03-04    12              12            27
# 661          West Ham  Home 2023-03-04    15              12            28
# 138    Crystal Palace  Home 2023-03-19    14              15            28
# 139      Leeds United  Home 2023-04-01    15              15             6
# 1836  Nott'ham Forest  Home 2023-04-22    15              15            16
# 1140          Everton  Home 2023-04-22    15              15            10
# 2194      Aston Villa  Home 2023-04-30    14              10             9
# 2365      Southampton  Home 2023-04-30    14              15             2
# 2203  Nott'ham Forest  Home 2023-08-26    15              12            28
# 2035           Fulham  Home 2023-09-02    15              12            16
# 1150           Wolves  Home 2023-09-03    14              15            23
# 2920    Sheffield Utd  Home 2023-09-16    15              12            21
# 2037  Nott'ham Forest  Home 2023-09-23    15              12             2
# 985       Aston Villa  Home 2023-09-24    14              12             9
# 154         Tottenham  Home 2023-09-24    14              15            23
# 2379   Crystal Palace  Home 2023-10-21    15              15            30
# 2044        Liverpool  Home 2023-11-25    12               1             3
# 2933          Everton  Home 2023-12-23    15              12            28
# 2050    Sheffield Utd  Home 2023-12-30    15              12             7

# %%
print(len(test))
print(len(test[test["actual"] == 1]))
print(int(len(test[test["actual"] == 1]) / len(test) * 10000) / 100, "%")
# Out:
# 24
# 20
# 83.33 %

# %%
correctW = 0
for index, entity in combinedWins.iterrows():
	if entity['actual'] == entity['predicted'] and entity['predicted'] == 1:
		correctW += 1

uncorrectW = len(combinedWins[combinedWins['predicted'] == 1]) - correctW

print("Wins:")
print("Correct:", correctW)
print("Wrong:", uncorrectW)
print("Ratio:", correctW / (correctW + uncorrectW) * 100, "%")
print("\n")
print(len(combinedWins[combinedWins['actual'] == combinedWins['predicted']]) / len(combinedWins))
# Out:
# Wins:
# Correct: 42
# Wrong: 24
# Ratio: 63.63636363636363 %
#
#
# 0.621256038647343
